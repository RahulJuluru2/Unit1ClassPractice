# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulJuluru2/Unit1ClassPractice/blob/main/B19sessionScipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $\int_{0}^2 x^2 dx$

# %%
def example(x):
  return x ** 2

# %%
from scipy import integrate

# %%
integrate?

# %%
result,error = integrate.quad(example,0,2)

# %%
print(result)
# Out:
# 2.666666666666667

# %%
import numpy as np

# %%
arr1 = np.array([[2,3],[3,4]])
arr2 = np.array([8,11])

# %%
from scipy import linalg

# %%
print(linalg.inv(arr1)@arr2)
# Out:
# [1. 2.]

# %%
x = linalg.solve(arr1,arr2)
x
# Out:
# array([1., 2.])

# %%
from scipy import misc
i1 = misc.face()
import matplotlib.pyplot as plt
plt.imshow(i1)

# %%
i1.shape
# Out:
# (768, 1024, 3)

# %%
#image is i1
flip_i1 = np.flipud(i1)
plt.imshow(flip_i1)

# %%
import imageio as io
i2 = io.imread('dog.jpg')
plt.imshow(i2)

# %%
i3 = i2 + 50

# %%
plt.imshow(i3)

# %%
i4 = io.imread('rect.png')
plt.imshow(i4)

# %%
from scipy import ndimage
fig=plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
result = ndimage.sobel(i4)
ax1.imshow(i4)
ax2.imshow(result);

# %%
plt.rcParams.get('figure.figsize')

# %%
i5 = io.imread('/content/imgedge.jpg')
plt.imshow(i5);

# %%
i5edge = ndimage.sobel(i5)
plt.imshow(i5edge);

# %%
arr5 = np.array([0,1,32,3,10])
arr6 = np.array([1,3,5,7,9])

# %%
from scipy import stats
slope,intercept,a1,b1,c1 =stats.linregress(arr5,arr6)  #machine Learning

# %%
print(slope)
print(intercept)

# %%
i6 = io.imread('horse.png')
plt.imshow(i6);

# %%
# !pip install handcalcs

# %%
import handcalcs.render

# %%
# %%render
# a = 2
# b = 3
# c = 2*a + b/3
# Out:
# \[
# \begin{aligned}
# a &= 2 \;
# \\[10pt]
# b &= 3 \;
# \\[10pt]
# c &= 2 \cdot a + \frac{ b }{ 3 }  = 2 \cdot 2 + \frac{ 3 }{ 3 } &= 5.0
# \end{aligned}
# \]

# %% [markdown]
# \begin{aligned}
# a &= 2 \;
# \\[10pt]
# b &= 3 \;
# \\[10pt]
# c &= 2 \cdot a + \frac{ b }{ 3 }  = 2 \cdot 2 + \frac{ 3 }{ 3 } &= 5.0
# \end{aligned}
